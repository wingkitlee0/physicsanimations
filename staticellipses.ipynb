# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt

# %%
def ellipse(a, ecc, pom, theta):
    r = a*(1.0-ecc**2)/(1.0-ecc*np.cos(theta-pom))
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x, y

rmin = 1.0
rmax = 10.0

fig, ax = plt.subplots(figsize=(6,6))
ax.axis("off")
ax.set_aspect("equal")
ax.set_xlim(-rmax*1.5,rmax*1.5)
ax.set_ylim(-rmax*1.5,rmax*1.5)
ax.scatter([0.0],[0.0],marker="*", s=200, c='C1')

nrings = 25

rmid = 0.5*(rmax+rmin)
tt = np.linspace(0.0, 2.0*np.pi, 200)
xx = np.linspace(0.0, 1.0, nrings)
aa = xx*(rmax-rmin)+rmin # semi-major axis
er = 0.1*np.exp(-( (aa-rmid)/2.0)**2)+0.1 # eccentricity
pr = 0.005*2.0*np.pi*np.ones((nrings,)) # precession rate

lines = []
for i, a in enumerate(aa):
    print(a, i)
    x, y = ellipse(a, er[i], 0.0, tt)
    line, = ax.fill(x,y, fill=False, lw=2, alpha=0.5)
    lines.append(line)
    
fig.savefig("epg.png", dpi=300)
# Out:
# 1.0 0
# 1.375 1
# 1.75 2
# 2.125 3
# 2.5 4
# 2.875 5
# 3.25 6
# 3.6249999999999996 7
# 4.0 8
# 4.375 9
# 4.75 10
# 5.125 11
# 5.5 12
# 5.875 13
# 6.249999999999999 14
# 6.625 15
# 7.0 16
# 7.374999999999999 17
# 7.75 18
# 8.125 19
# 8.5 20
# 8.875 21
# 9.25 22
# 9.625 23
# 10.0 24

# %%
def ellipse(a, ecc, pom, theta):
    r = a*(1.0-ecc**2)/(1.0-ecc*np.cos(theta-pom))
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x, y

rmin = 1.0
rmax = 10.0

fig, ax = plt.subplots(figsize=(6,6))
ax.axis("off")
ax.set_aspect("equal")
ax.set_xlim(-rmax*1.5,rmax*1.5)
ax.set_ylim(-rmax*1.5,rmax*1.5)
ax.scatter([0.0],[0.0],marker="*", s=200, c='C1')

nrings = 25

rmid = 0.5*(rmax+rmin)
tt = np.linspace(0.0, 2.0*np.pi, 200)
xx = np.linspace(0.0, 1.0, nrings)
aa = xx*(rmax-rmin)+rmin # semi-major axis
#er = 0.1*np.exp(-( (aa-rmid)/2.0)**2)+0.1 # eccentricity
er = xx*0.1
pom= 0.0*np.ones((nrings,))
pr = 0.005*2.0*np.pi*np.ones((nrings,)) # precession rate

lines = []
for i, a in enumerate(aa):
    print(a, i)
    x, y = ellipse(a, er[i], pom[i], tt)
    line, = ax.fill(x,y, fill=False, lw=2, alpha=0.5)
    lines.append(line)
    
fig.savefig("ep.png", dpi=300)
# Out:
# 1.0 0
# 1.375 1
# 1.75 2
# 2.125 3
# 2.5 4
# 2.875 5
# 3.25 6
# 3.6249999999999996 7
# 4.0 8
# 4.375 9
# 4.75 10
# 5.125 11
# 5.5 12
# 5.875 13
# 6.249999999999999 14
# 6.625 15
# 7.0 16
# 7.374999999999999 17
# 7.75 18
# 8.125 19
# 8.5 20
# 8.875 21
# 9.25 22
# 9.625 23
# 10.0 24

# %%
def ellipse(a, ecc, pom, theta):
    r = a*(1.0-ecc**2)/(1.0-ecc*np.cos(theta-pom))
    x = r*np.cos(theta)
    y = r*np.sin(theta)
    return x, y

rmin = 1.0
rmax = 10.0

fig, ax = plt.subplots(figsize=(6,6))
ax.axis("off")
ax.set_aspect("equal")
ax.set_xlim(-rmax*1.5,rmax*1.5)
ax.set_ylim(-rmax*1.5,rmax*1.5)
ax.scatter([0.0],[0.0],marker="*", s=200, c='C1')

nrings = 20

rmid = 0.5*(rmax+rmin)
tt = np.linspace(0.0, 2.0*np.pi, 200)
xx = np.linspace(0.0, 1.0, nrings)
aa = xx*(rmax-rmin)+rmin # semi-major axis
er = 0.1*np.exp(-( (aa-rmid)/2.0)**2)+0.1 # eccentricity
#er = xx*0.1
pom=-xx*np.pi*2.0
pr = 0.005*2.0*np.pi*np.ones((nrings,)) # precession rate

lines = []
for i, a in enumerate(aa):
    print(a, i)
    x, y = ellipse(a, er[i], pom[i], tt)
    line, = ax.fill(x,y, fill=False, lw=2, alpha=0.5)
    lines.append(line)
    
fig.savefig("s.png", dpi=300)
# Out:
# 1.0 0
# 1.4736842105263157 1
# 1.9473684210526314 2
# 2.4210526315789473 3
# 2.894736842105263 4
# 3.3684210526315788 5
# 3.8421052631578947 6
# 4.315789473684211 7
# 4.789473684210526 8
# 5.263157894736842 9
# 5.7368421052631575 10
# 6.210526315789474 11
# 6.684210526315789 12
# 7.157894736842104 13
# 7.63157894736842 14
# 8.105263157894736 15
# 8.578947368421051 16
# 9.052631578947368 17
# 9.526315789473683 18
# 10.0 19
